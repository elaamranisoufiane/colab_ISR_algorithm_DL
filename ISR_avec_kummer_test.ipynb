# %%
# !git clone https://github.com/fannymonori/TF-LapSRN.git
# Out:
# Cloning into 'TF-LapSRN'...
# remote: Enumerating objects: 135, done.
# remote: Total 135 (delta 0), reused 0 (delta 0), pack-reused 135
# Receiving objects: 100% (135/135), 42.90 MiB | 22.61 MiB/s, done.
# Resolving deltas: 100% (12/12), done.

# %%
# !git clone https://github.com/Saafke/EDSR_Tensorflow.git
# Out:
# Cloning into 'EDSR_Tensorflow'...
# remote: Enumerating objects: 149, done.
# remote: Counting objects: 100% (6/6), done.
# remote: Compressing objects: 100% (6/6), done.
# remote: Total 149 (delta 1), reused 0 (delta 0), pack-reused 143
# Receiving objects: 100% (149/149), 162.50 MiB | 23.14 MiB/s, done.
# Resolving deltas: 100% (77/77), done.

# %%
# !git clone https://github.com/elaamranisoufiane/kmms_test1.git
# Out:
# Cloning into 'kmms_test1'...
# remote: Enumerating objects: 104, done.
# remote: Counting objects: 100% (104/104), done.
# remote: Compressing objects: 100% (104/104), done.
# remote: Total 104 (delta 0), reused 104 (delta 0), pack-reused 0
# Receiving objects: 100% (104/104), 7.42 MiB | 17.59 MiB/s, done.

# %%
import cv2
import glob
import matplotlib.pyplot as plt
import time
from google.colab.patches import cv2_imshow

#pathmasks="/content/kmms_test1/masks/*.jpg"
pathimages="/content/kmms_test1/masks/*.png"



def save(image, path):
  cv2.imwrite(path, image)
  print("saved!")

def ISR(img, save_path):
  img=cv2.imread(f"{img}")
  width = img.shape[1]
  height = img.shape[0]
  print(width)
  super_res = cv2.dnn_superres.DnnSuperResImpl_create()
  start = time.time()
  super_res.readModel('/content/TF-LapSRN/export/LapSRN_x4.pb')
  super_res.setModel('lapsrn',4)
  lapsrn_image = super_res.upsample(img)
  end = time.time()
  print('Time taken in seconds by lapsrn', end-start)
  save(lapsrn_image, save_path)

count=0;

images=[image for image in glob.glob(pathimages)]
#masks=[mask for mask in glob.glob(pathmasks)]
print(pathimages)
#fig=plt.figure()
for i in range(len(images)):
  name = images[i].split("/")[-1]
  save_path_images = f"/content/kmms_test1_1024/masks/{name}"
  ISR(images[i], save_path_images)
  print(count)
  count=count+1
  #ISR(images[i])
  '''
for i in range(len(masks)):
  name = masks[i].split("/")[-1]
  save_path_masks = f"/content/DSB2/masks/{name}"
  ISR(masks[i], save_path_masks)
  print(count)
  count=count+1
  #ISR(images[i]) '''
# Out:
# /content/kmms_test1/masks/*.png
# 256
# Time taken in seconds by lapsrn 8.583995819091797
# saved!
# 0
# 256
# Time taken in seconds by lapsrn 8.191709518432617
# saved!
# 1
# 256
# Time taken in seconds by lapsrn 4.551650285720825
# saved!
# 2
# 256
# Time taken in seconds by lapsrn 5.49805760383606
# saved!
# 3
# 256
# Time taken in seconds by lapsrn 4.272268295288086
# saved!
# 4
# 256
# Time taken in seconds by lapsrn 4.289232969284058
# saved!
# 5
# 256
# Time taken in seconds by lapsrn 5.531260251998901
# saved!
# 6
# 256
# Time taken in seconds by lapsrn 4.281696081161499
# saved!
# 7
# 256
# Time taken in seconds by lapsrn 4.767822980880737
# saved!
# 8
# 256
# Time taken in seconds by lapsrn 4.9883434772491455
# saved!
# 9
# 256
# Time taken in seconds by lapsrn 4.267096042633057
# saved!
# 10
# 256
# Time taken in seconds by lapsrn 5.262281656265259
# saved!
# 11
# 256
# Time taken in seconds by lapsrn 4.305250883102417
# saved!
# 12
# 256
# Time taken in seconds by lapsrn 4.461990118026733
# saved!
# 13
# 256
# Time taken in seconds by lapsrn 5.5319836139678955
# saved!
# 14
# 256
# Time taken in seconds by lapsrn 4.299991130828857
# saved!
# 15
# 256
# Time taken in seconds by lapsrn 4.286494731903076
# saved!
# 16
# 256
# Time taken in seconds by lapsrn 5.600241422653198
# saved!
# 17
# 256
# Time taken in seconds by lapsrn 4.214882135391235
# saved!
# 18
# 256
# Time taken in seconds by lapsrn 4.802895784378052
# saved!
# 19
# 256
# Time taken in seconds by lapsrn 4.979688882827759
# saved!
# 20
# 256
# Time taken in seconds by lapsrn 4.253383159637451
# saved!
# 21
# 256
# Time taken in seconds by lapsrn 5.535043478012085
# saved!
# 22
# 256
# Time taken in seconds by lapsrn 4.359241962432861
# saved!
# 23
# 256
# Time taken in seconds by lapsrn 4.385987281799316
# saved!
# 24
# 256
# Time taken in seconds by lapsrn 5.636646509170532
# saved!
# 25
# 256
# Time taken in seconds by lapsrn 4.359136581420898
# saved!
# 26
# 256
# Time taken in seconds by lapsrn 4.551085948944092
# saved!
# 27
# 256
# Time taken in seconds by lapsrn 5.42961311340332
# saved!
# 28
# 256
# Time taken in seconds by lapsrn 4.421310663223267
# saved!
# 29
# 256
# Time taken in seconds by lapsrn 5.482902526855469
# saved!
# 30
# 256
# Time taken in seconds by lapsrn 4.4196860790252686
# saved!
# 31
# 256
# Time taken in seconds by lapsrn 4.273627758026123
# saved!
# 32
# 256
# Time taken in seconds by lapsrn 5.584894418716431
# saved!
# 33
# 256
# Time taken in seconds by lapsrn 4.312466382980347
# saved!
# 34
# 256
# Time taken in seconds by lapsrn 4.399348258972168
# saved!
# 35
# 256
# Time taken in seconds by lapsrn 5.5460357666015625
# saved!
# 36
# 256
# Time taken in seconds by lapsrn 4.285464525222778
# saved!
# 37
# 256
# Time taken in seconds by lapsrn 4.686510324478149
# saved!
# 38
# 256
# Time taken in seconds by lapsrn 5.0950751304626465
# saved!
# 39
# 256
# Time taken in seconds by lapsrn 4.297104358673096
# saved!
# 40
# 256
# Time taken in seconds by lapsrn 5.318453073501587
# saved!
# 41
# 256
# Time taken in seconds by lapsrn 4.22029185295105
# saved!
# 42
# 256
# Time taken in seconds by lapsrn 4.216925859451294
# saved!
# 43
# 256
# Time taken in seconds by lapsrn 5.429306268692017
# saved!
# 44
# 256
# Time taken in seconds by lapsrn 4.175976276397705
# saved!
# 45
# 256
# Time taken in seconds by lapsrn 4.2474706172943115
# saved!
# 46
# 256
# Time taken in seconds by lapsrn 5.4679412841796875
# saved!
# 47
# 256
# Time taken in seconds by lapsrn 4.345589876174927
# saved!
# 48
# 256
# Time taken in seconds by lapsrn 4.499721527099609
# saved!
# 49

# %%
# !zip -r ./kmms_test1_1024.zip /content/kmms_test1_1024
# Out:
#   adding: content/kmms_test1_1024/ (stored 0%)
#   adding: content/kmms_test1_1024/images/ (stored 0%)
#   adding: content/kmms_test1_1024/images/10_1.png (deflated 2%)
#   adding: content/kmms_test1_1024/images/04_3.png (deflated 4%)
#   adding: content/kmms_test1_1024/images/03_5.png (deflated 3%)
#   adding: content/kmms_test1_1024/images/01_6.png (deflated 4%)
#   adding: content/kmms_test1_1024/images/05_2.png (deflated 2%)
#   adding: content/kmms_test1_1024/images/05_1.png (deflated 2%)
#   adding: content/kmms_test1_1024/images/04_2.png (deflated 3%)
#   adding: content/kmms_test1_1024/images/02_1.png (deflated 4%)
#   adding: content/kmms_test1_1024/images/03_4.png (deflated 4%)
#   adding: content/kmms_test1_1024/images/04_8.png (deflated 1%)
#   adding: content/kmms_test1_1024/images/11_1.png (deflated 2%)
#   adding: content/kmms_test1_1024/images/09_1.png (deflated 2%)
#   adding: content/kmms_test1_1024/images/07_3.png (deflated 2%)
#   adding: content/kmms_test1_1024/images/07_2.png (deflated 2%)
#   adding: content/kmms_test1_1024/images/06_1.png (deflated 3%)
#   adding: content/kmms_test1_1024/images/01_5.png (deflated 3%)
#   adding: content/kmms_test1_1024/images/08_4.png (deflated 3%)
#   adding: content/kmms_test1_1024/images/05_4.png (deflated 2%)
#   adding: content/kmms_test1_1024/images/04_4.png (deflated 1%)
#   adding: content/kmms_test1_1024/images/10_3.png (deflated 2%)
#   adding: content/kmms_test1_1024/images/10_2.png (deflated 4%)
#   adding: content/kmms_test1_1024/images/09_6.png (deflated 3%)
#   adding: content/kmms_test1_1024/images/09_5.png (deflated 3%)
#   adding: content/kmms_test1_1024/images/06_3.png (deflated 3%)
#   adding: content/kmms_test1_1024/images/02_2.png (deflated 4%)
#   adding: content/kmms_test1_1024/images/04_5.png (deflated 4%)
#   adding: content/kmms_test1_1024/images/02_3.png (deflated 4%)
#   adding: content/kmms_test1_1024/images/11_3.png (deflated 3%)
#   adding: content/kmms_test1_1024/images/05_3.png (deflated 2%)
#   adding: content/kmms_test1_1024/images/01_7.png (deflated 3%)
#   adding: content/kmms_test1_1024/images/09_2.png (deflated 1%)
#   adding: content/kmms_test1_1024/images/04_1.png (deflated 2%)
#   adding: content/kmms_test1_1024/images/01_2.png (deflated 2%)
#   adding: content/kmms_test1_1024/images/01_1.png (deflated 3%)
#   adding: content/kmms_test1_1024/images/10_4.png (deflated 2%)
#   adding: content/kmms_test1_1024/images/03_3.png (deflated 2%)
#   adding: content/kmms_test1_1024/images/07_1.png (deflated 2%)
#   adding: content/kmms_test1_1024/images/08_2.png (deflated 3%)
#   adding: content/kmms_test1_1024/images/03_2.png (deflated 2%)
#   adding: content/kmms_test1_1024/images/01_3.png (deflated 2%)
#   adding: content/kmms_test1_1024/images/03_1.png (deflated 2%)
#   adding: content/kmms_test1_1024/images/04_6.png (deflated 2%)
#   adding: content/kmms_test1_1024/images/08_1.png (deflated 2%)
#   adding: content/kmms_test1_1024/images/11_2.png (deflated 2%)
#   adding: content/kmms_test1_1024/images/06_2.png (deflated 3%)
#   adding: content/kmms_test1_1024/images/09_4.png (deflated 2%)
#   adding: content/kmms_test1_1024/images/08_3.png (deflated 3%)
#   adding: content/kmms_test1_1024/images/04_7.png (deflated 2%)
#   adding: content/kmms_test1_1024/images/09_3.png (deflated 1%)
#   adding: content/kmms_test1_1024/images/01_4.png (deflated 1%)
#   adding: content/kmms_test1_1024/masks/ (stored 0%)
#   adding: content/kmms_test1_1024/masks/10_1.png (deflated 19%)
#   adding: content/kmms_test1_1024/masks/04_3.png (deflated 24%)
#   adding: content/kmms_test1_1024/masks/03_5.png (deflated 19%)
#   adding: content/kmms_test1_1024/masks/01_6.png (deflated 24%)
#   adding: content/kmms_test1_1024/masks/05_2.png (deflated 19%)
#   adding: content/kmms_test1_1024/masks/05_1.png (deflated 19%)
#   adding: content/kmms_test1_1024/masks/04_2.png (deflated 24%)
#   adding: content/kmms_test1_1024/masks/02_1.png (deflated 21%)
#   adding: content/kmms_test1_1024/masks/03_4.png (deflated 21%)
#   adding: content/kmms_test1_1024/masks/04_8.png (deflated 18%)
#   adding: content/kmms_test1_1024/masks/11_1.png (deflated 19%)
#   adding: content/kmms_test1_1024/masks/09_1.png (deflated 20%)
#   adding: content/kmms_test1_1024/masks/07_3.png (deflated 18%)
#   adding: content/kmms_test1_1024/masks/07_2.png (deflated 19%)
#   adding: content/kmms_test1_1024/masks/06_1.png (deflated 19%)
#   adding: content/kmms_test1_1024/masks/01_5.png (deflated 18%)
#   adding: content/kmms_test1_1024/masks/08_4.png (deflated 19%)
#   adding: content/kmms_test1_1024/masks/05_4.png (deflated 20%)
#   adding: content/kmms_test1_1024/masks/04_4.png (deflated 19%)
#   adding: content/kmms_test1_1024/masks/10_3.png (deflated 19%)
#   adding: content/kmms_test1_1024/masks/10_2.png (deflated 20%)
#   adding: content/kmms_test1_1024/masks/09_6.png (deflated 30%)
#   adding: content/kmms_test1_1024/masks/09_5.png (deflated 19%)
#   adding: content/kmms_test1_1024/masks/06_3.png (deflated 20%)
#   adding: content/kmms_test1_1024/masks/02_2.png (deflated 19%)
#   adding: content/kmms_test1_1024/masks/04_5.png (deflated 25%)
#   adding: content/kmms_test1_1024/masks/02_3.png (deflated 19%)
#   adding: content/kmms_test1_1024/masks/11_3.png (deflated 19%)
#   adding: content/kmms_test1_1024/masks/05_3.png (deflated 19%)
#   adding: content/kmms_test1_1024/masks/01_7.png (deflated 19%)
#   adding: content/kmms_test1_1024/masks/09_2.png (deflated 20%)
#   adding: content/kmms_test1_1024/masks/04_1.png (deflated 18%)
#   adding: content/kmms_test1_1024/masks/01_2.png (deflated 18%)
#   adding: content/kmms_test1_1024/masks/01_1.png (deflated 19%)
#   adding: content/kmms_test1_1024/masks/10_4.png (deflated 23%)
#   adding: content/kmms_test1_1024/masks/03_3.png (deflated 21%)
#   adding: content/kmms_test1_1024/masks/07_1.png (deflated 19%)
#   adding: content/kmms_test1_1024/masks/08_2.png (deflated 19%)
#   adding: content/kmms_test1_1024/masks/03_2.png (deflated 19%)
#   adding: content/kmms_test1_1024/masks/01_3.png (deflated 21%)
#   adding: content/kmms_test1_1024/masks/03_1.png (deflated 19%)
#   adding: content/kmms_test1_1024/masks/04_6.png (deflated 19%)
#   adding: content/kmms_test1_1024/masks/08_1.png (deflated 19%)
#   adding: content/kmms_test1_1024/masks/11_2.png (deflated 20%)
#   adding: content/kmms_test1_1024/masks/06_2.png (deflated 20%)
#   adding: content/kmms_test1_1024/masks/09_4.png (deflated 19%)
#   adding: content/kmms_test1_1024/masks/08_3.png (deflated 20%)
#   adding: content/kmms_test1_1024/masks/04_7.png (deflated 20%)
#   adding: content/kmms_test1_1024/masks/09_3.png (deflated 20%)
#   adding: content/kmms_test1_1024/masks/01_4.png (deflated 19%)
#   adding: content/kmms_test1_1024/.ipynb_checkpoints/ (stored 0%)
